# %%
# !pip install dune-client
# Out:
# Collecting dune-client
#   Downloading dune_client-1.10.0-py3-none-any.whl.metadata (6.9 kB)
# Collecting aiohttp~=3.12.15 (from dune-client)
#   Downloading aiohttp-3.12.15-cp313-cp313-win_amd64.whl.metadata (7.9 kB)
# Collecting dataclasses-json~=0.6.4 (from dune-client)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting deprecated~=1.2.18 (from dune-client)
#   Downloading Deprecated-1.2.18-py2.py3-none-any.whl.metadata (5.7 kB)
# Collecting ndjson~=0.3.1 (from dune-client)
#   Downloading ndjson-0.3.1-py2.py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: python-dateutil~=2.9.0 in c:\users\water\anaconda3\lib\site-packages (from dune-client) (2.9.0.post0)
# Requirement already satisfied: requests~=2.32.5 in c:\users\water\anaconda3\lib\site-packages (from dune-client) (2.32.5)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\water\anaconda3\lib\site-packages (from aiohttp~=3.12.15->dune-client) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\water\anaconda3\lib\site-packages (from aiohttp~=3.12.15->dune-client) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\water\anaconda3\lib\site-packages (from aiohttp~=3.12.15->dune-client) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\water\anaconda3\lib\site-packages (from aiohttp~=3.12.15->dune-client) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\water\anaconda3\lib\site-packages (from aiohttp~=3.12.15->dune-client) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\water\anaconda3\lib\site-packages (from aiohttp~=3.12.15->dune-client) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\water\anaconda3\lib\site-packages (from aiohttp~=3.12.15->dune-client) (1.22.0)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json~=0.6.4->dune-client)
#   Downloading marshmallow-3.26.2-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json~=0.6.4->dune-client)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\water\anaconda3\lib\site-packages (from deprecated~=1.2.18->dune-client) (1.17.0)
# Requirement already satisfied: packaging>=17.0 in c:\users\water\anaconda3\lib\site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json~=0.6.4->dune-client) (25.0)
# Requirement already satisfied: six>=1.5 in c:\users\water\anaconda3\lib\site-packages (from python-dateutil~=2.9.0->dune-client) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\water\anaconda3\lib\site-packages (from requests~=2.32.5->dune-client) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\water\anaconda3\lib\site-packages (from requests~=2.32.5->dune-client) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\water\anaconda3\lib\site-packages (from requests~=2.32.5->dune-client) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\water\anaconda3\lib\site-packages (from requests~=2.32.5->dune-client) (2026.1.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\water\anaconda3\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json~=0.6.4->dune-client) (1.0.0)
# Requirement already satisfied: typing-extensions>=3.7.4 in c:\users\water\anaconda3\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json~=0.6.4->dune-client) (4.15.0)
# Downloading dune_client-1.10.0-py3-none-any.whl (42 kB)
# Downloading aiohttp-3.12.15-cp313-cp313-win_amd64.whl (449 kB)
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading Deprecated-1.2.18-py2.py3-none-any.whl (10.0 kB)
# Downloading marshmallow-3.26.2-py3-none-any.whl (50 kB)
# Downloading ndjson-0.3.1-py2.py3-none-any.whl (5.3 kB)
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Installing collected packages: ndjson, typing-inspect, marshmallow, deprecated, dataclasses-json, aiohttp, dune-client
#
#    ---------------------- ----------------- 4/7 [dataclasses-json]
#   Attempting uninstall: aiohttp
#    ---------------------- ----------------- 4/7 [dataclasses-json]
#     Found existing installation: aiohttp 3.13.2
#    ---------------------- ----------------- 4/7 [dataclasses-json]
#     Uninstalling aiohttp-3.13.2:
#    ---------------------- ----------------- 4/7 [dataclasses-json]
#       Successfully uninstalled aiohttp-3.13.2
#    ---------------------- ----------------- 4/7 [dataclasses-json]
#    ---------------------------- ----------- 5/7 [aiohttp]
#    ---------------------------- ----------- 5/7 [aiohttp]
#    ---------------------------- ----------- 5/7 [aiohttp]
#    ---------------------------- ----------- 5/7 [aiohttp]
#    ---------------------------- ----------- 5/7 [aiohttp]
#    ---------------------------- ----------- 5/7 [aiohttp]
#    ---------------------------- ----------- 5/7 [aiohttp]
#    ---------------------------- ----------- 5/7 [aiohttp]
#    ---------------------------- ----------- 5/7 [aiohttp]
#    ---------------------------- ----------- 5/7 [aiohttp]
#    ---------------------------- ----------- 5/7 [aiohttp]
#    ---------------------------- ----------- 5/7 [aiohttp]
#    ---------------------------- ----------- 5/7 [aiohttp]
#    ---------------------------- ----------- 5/7 [aiohttp]
#    ---------------------------- ----------- 5/7 [aiohttp]
#    ---------------------------- ----------- 5/7 [aiohttp]
#    ---------------------------- ----------- 5/7 [aiohttp]
#    ---------------------------- ----------- 5/7 [aiohttp]
#    ---------------------------- ----------- 5/7 [aiohttp]
#    ---------------------------- ----------- 5/7 [aiohttp]
#    ---------------------------------- ----- 6/7 [dune-client]
#    ---------------------------------------- 7/7 [dune-client]
#
# Successfully installed aiohttp-3.12.15 dataclasses-json-0.6.7 deprecated-1.2.18 dune-client-1.10.0 marshmallow-3.26.2 ndjson-0.3.1 typing-inspect-0.9.0
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\water\anaconda3\Lib\site-packages\~iohttp'.
#   You can safely remove it manually.

# %%
import pandas as pd
from dune_client.client import DuneClient

dune = DuneClient("0dJpl8lukKJkUHWgjm0D5o1HRqgTtASU")

query_result = dune.get_latest_result(6991784)
df = pd.DataFrame(query_result.result.rows)
print(df.shape)
df.head()
# Out:
# (1000, 5)
#      amount_usd                   block_time  token  \
# 0  2.062540e+07  2026-04-09 20:43:23.000 UTC  PYUSD
# 1  2.062193e+07  2026-04-09 20:43:23.000 UTC   USDC
# 2  1.803570e+07  2026-04-09 20:43:23.000 UTC   USDS
# 3  1.801601e+07  2026-04-09 20:43:23.000 UTC  PYUSD
# 4  9.502865e+06  2026-04-09 15:09:47.000 UTC   USDS
#
#                                              tx_hash  \
# 0  0x346cdde5d0b05ef35b240442d762f8d9c5cf85d1212e...
# 1  0x346cdde5d0b05ef35b240442d762f8d9c5cf85d1212e...
# 2  0x261cb1494e8d002407f8ed4b46ba8d4b8eaa8e2baa43...
# 3  0x261cb1494e8d002407f8ed4b46ba8d4b8eaa8e2baa43...
# 4  0x2410296ccb6449abce44efeea4fc9deeeca39b00e3b2...
#
#                                        wallet
# 0  0x555f240e556788e65306754a0ba6e7a76c2ab59e
# 1  0x555f240e556788e65306754a0ba6e7a76c2ab59e
# 2  0x555f240e556788e65306754a0ba6e7a76c2ab59e
# 3  0x555f240e556788e65306754a0ba6e7a76c2ab59e
# 4  0x63242a4ea82847b20e506b63b0e2e2eff0cc6cb0

# %%
df['amount_usd'] = df['amount_usd'].astype(float)
print(df['amount_usd'].describe())
# Out:
# count    1.000000e+03
# mean     2.319882e+06
# std      2.190945e+06
# min      9.524323e+05
# 25%      1.072670e+06
# 50%      1.480042e+06
# 75%      2.456056e+06
# max      2.062540e+07
# Name: amount_usd, dtype: float64

# %%
# Top 10 whales by total volume
whales = df.groupby('wallet')['amount_usd'].agg(
    total_volume='sum',
    trade_count='count',
    avg_trade='mean'
).sort_values('total_volume', ascending=False).head(10)

whales['total_volume'] = whales['total_volume'].round(0)
whales['avg_trade'] = whales['avg_trade'].round(0)

print(whales)
# Out:
#                                             total_volume  trade_count  \
# wallet
# 0x555f240e556788e65306754a0ba6e7a76c2ab59e   387620910.0           81
# 0x1f2f10d1c40777ae1da742455c65828ff36df387   354800976.0          236
# 0xc3623ab16de256bf11855f884fdffd6f971c5fb7   271675201.0           56
# 0x63242a4ea82847b20e506b63b0e2e2eff0cc6cb0   256123760.0          143
# 0xbab386a3220234f7cce09b3794e9b5a2f44ce775   164116337.0           24
# 0x0906a879ea0f66e3559f11b25b866dba247f9e63    77745572.0           32
# 0xf48a3f7c0575c85cf4529aa220caf3c055773f1c    70905556.0           60
# 0x5814fc20f0e09114503569ed6b27a4a86c9f8de4    60750209.0           18
# 0x654fae4aa229d104cabead47e56703f58b174be4    50317065.0           18
# 0x6e6759b3ef49bab693127c9ea126eb6e549bc3d3    41815459.0           22
#
#                                             avg_trade
# wallet
# 0x555f240e556788e65306754a0ba6e7a76c2ab59e  4785443.0
# 0x1f2f10d1c40777ae1da742455c65828ff36df387  1503394.0
# 0xc3623ab16de256bf11855f884fdffd6f971c5fb7  4851343.0
# 0x63242a4ea82847b20e506b63b0e2e2eff0cc6cb0  1791075.0
# 0xbab386a3220234f7cce09b3794e9b5a2f44ce775  6838181.0
# 0x0906a879ea0f66e3559f11b25b866dba247f9e63  2429549.0
# 0xf48a3f7c0575c85cf4529aa220caf3c055773f1c  1181759.0
# 0x5814fc20f0e09114503569ed6b27a4a86c9f8de4  3375012.0
# 0x654fae4aa229d104cabead47e56703f58b174be4  2795392.0
# 0x6e6759b3ef49bab693127c9ea126eb6e549bc3d3  1900703.0

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(10, 6))

labels = [w[:8] + '...' for w in whales.index]
bars = ax.barh(labels, whales['total_volume'] / 1e6, color='steelblue')

ax.set_xlabel('Total Volume ($ millions)')
ax.set_title('Top 10 Ethereum Whales — 7 Day Trading Volume')
ax.bar_label(bars, fmt='$%.0fM', padding=3)

plt.tight_layout()
plt.savefig('whale_chart.png')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 6))

ax.scatter(whales['trade_count'], whales['total_volume'] / 1e6, 
           color='#00BFFF', s=200, alpha=0.8)

for i, wallet in enumerate(whales.index):
    ax.annotate(wallet[:8] + '...', 
                (whales['trade_count'].iloc[i], whales['total_volume'].iloc[i] / 1e6),
                textcoords="offset points", xytext=(8, 4), fontsize=8, color='white')

ax.set_xlabel('Number of Trades', color='white')
ax.set_ylabel('Total Volume ($ millions)', color='white')
ax.set_title('Whale Types — Volume vs Trade Frequency', color='white')
ax.tick_params(colors='white')

plt.tight_layout()
plt.savefig('whale_scatter.png', facecolor='#1a1a2e')
plt.show()

# %%
# Classify whales by behavior
df_whales = df[df['wallet'].isin(whales.index)].copy()

whale_types = []
for wallet in whales.index:
    trades = whales.loc[wallet, 'trade_count']
    avg = whales.loc[wallet, 'avg_trade']
    
    if trades > 100:
        whale_type = 'Bot / HFT'
    elif avg > 5000000:
        whale_type = 'Mega Whale'
    else:
        whale_type = 'Active Whale'
    
    whale_types.append({'wallet': wallet[:8] + '...', 'type': whale_type, 
                        'total_volume_M': round(whales.loc[wallet, 'total_volume'] / 1e6, 1),
                        'trade_count': trades,
                        'avg_trade_M': round(avg / 1e6, 2)})

whale_df = pd.DataFrame(whale_types)
print(whale_df.to_string(index=False))
# Out:
#      wallet         type  total_volume_M  trade_count  avg_trade_M
# 0x555f24... Active Whale           387.6           81         4.79
# 0x1f2f10...    Bot / HFT           354.8          236         1.50
# 0xc3623a... Active Whale           271.7           56         4.85
# 0x63242a...    Bot / HFT           256.1          143         1.79
# 0xbab386...   Mega Whale           164.1           24         6.84
# 0x0906a8... Active Whale            77.7           32         2.43
# 0xf48a3f... Active Whale            70.9           60         1.18
# 0x5814fc... Active Whale            60.8           18         3.38
# 0x654fae... Active Whale            50.3           18         2.80
# 0x6e6759... Active Whale            41.8           22         1.90

# %%
# Top tokens traded by whales
top_tokens = df.groupby('token')['amount_usd'].agg(
    total_volume='sum',
    trade_count='count'
).sort_values('total_volume', ascending=False).head(10)

top_tokens['total_volume_M'] = (top_tokens['total_volume'] / 1e6).round(1)
print(top_tokens[['total_volume_M', 'trade_count']])
# Out:
#        total_volume_M  trade_count
# token
# USDC            916.8          370
# USDT            826.7          330
# WETH            133.0           71
# PYUSD           122.8           50
# USDS             73.6           29
# sUSDS            31.6           21
# WBTC             29.7           15
# RLUSD            28.0           12
# 7AΩ∞             27.5           12
# weETH            24.9           16

# %%
fig, ax = plt.subplots(figsize=(10, 6))

bars = ax.barh(top_tokens.index, top_tokens['total_volume_M'], color='#00BFFF')
ax.set_xlabel('Total Volume ($ millions)', color='white')
ax.set_title('Top Tokens Traded by Whales — 7 Days', color='white')
ax.bar_label(bars, fmt='$%.0fM', padding=3, color='white')
ax.tick_params(colors='white')

plt.tight_layout()
plt.savefig('whale_tokens.png', facecolor='#1a1a2e')
plt.show()

# %%
# Trading activity by hour
df['hour'] = pd.to_datetime(df['block_time']).dt.hour

hourly = df.groupby('hour')['amount_usd'].agg(
    total_volume='sum',
    trade_count='count'
).reset_index()

fig, ax = plt.subplots(figsize=(12, 5))
ax.bar(hourly['hour'], hourly['total_volume'] / 1e6, color='#00BFFF', alpha=0.8)
ax.set_xlabel('Hour (UTC)', color='white')
ax.set_ylabel('Total Volume ($ millions)', color='white')
ax.set_title('Whale Trading Activity by Hour of Day', color='white')
ax.set_xticks(range(0, 24))
ax.tick_params(colors='white')

plt.tight_layout()
plt.savefig('whale_hourly.png', facecolor='#1a1a2e')
plt.show()

# %% [markdown]
# ## Summary & Business Findings
#
# ### What I analyzed
# Extracted 1,000 largest DEX trades on Ethereum over 7 days (min $100,000 per trade)
# using Dune Analytics API. Identified top whale wallets and analyzed their behavior.
#
# ### Key Findings
#
# **1. Whale Classification**
# - 2 wallets identified as Bots/HFT — 143-236 trades/week, avg $1.5-1.8M per trade
# - 1 Mega Whale — only 24 trades but avg $6.84M per trade
# - 7 Active Whales — moderate frequency, $2-5M avg trade size
#
# **2. Token Preference**
# - 87% of whale volume is stablecoins (USDC $917M + USDT $827M)
# - Whales are moving liquidity, not speculating on price
#
# **3. Time Patterns**
# - Peak activity at 16:00 UTC (NYSE open)
# - Low activity 3-5 UTC (night in US + Europe)
# - Whales follow traditional market hours — likely institutional players
#
# ### Conclusion
# Ethereum whale activity is dominated by institutional players and bots.
# Their stablecoin preference suggests liquidity management, not speculation.
# Monitoring these wallets can provide early signals of large market movements.
#
# ### Tools
# Python, Pandas, Matplotlib, Dune Analytics API
